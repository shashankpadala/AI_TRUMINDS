# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_boston 
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import scorer, accuracy_score, f1_score, confusion_matrix, roc_auc_score
from sklearn.model_selection import train_test_split
from collections import Counter
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score, make_scorer
from time import time
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import LinearSVC
from sklearn.ensemble import AdaBoostClassifier, RandomForestClassifier, BaggingClassifier
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.externals import joblib
import xgboost as xgb
import pickle
import nltk
nltk.download('punkt')
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.metrics.scorer module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# !pip install tensorflow
# !pip install tensorflow-hub
# !pip install sentencepiece
import tensorflow as tf
import tensorflow_hub as hub
print("TF version: ", tf.__version__)
print("Hub version: ", hub.__version__)
import pandas as pd
import numpy as np
import spacy
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import regex as re
import string
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_colwidth', None)
import tensorflow.keras
import sklearn
from tensorflow.keras import layers
from tensorflow.keras import Model
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.layers import Dense, Input, Dropout, GlobalAveragePooling1D
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import LinearSVC
from sklearn.ensemble import AdaBoostClassifier, RandomForestClassifier, BaggingClassifier
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
# Out:
# ...
#      |████████████████████████████████| 1.2MB 17.0MB/s
# ...
# TF version:  2.4.1
# Hub version:  0.11.0

# %%
data=pd.read_excel('/content/drive/MyDrive/hatespeech/Data Sample.xlsx')

# %%
data
# Out:
#        index  ...                                                                                                           clean_tweet
# 0          0  ...   rt as a woman you shouldn t complain about cleaning up your house amp as a man you should always take the trash out
# 1          1  ...                                                     rt boy dats cold tyga dwn bad for cuffin dat hoe in the 1st place
# 2          2  ...                                         rt dawg rt you ever fuck a bitch and she start to cry you be confused as shit
# 3          3  ...                                                                            rt g anderson based she look like a tranny
# 4          4  ...               rt the shit you hear about me might be true or it might be faker than the bitch who told it to ya 57361
# ...      ...  ...                                                                                                                   ...
# ...

# %%
data=data.drop(columns=['index','count','offensive_language','neither','class','clean_tweet'])

# %%
for i in data.hate_speech:
  if(i>0):
    data['hate_speech']=data['hate_speech'].replace([i],1)

# %%
data['hate_speech'].value_counts()
# Out:
# 0    16815
# 1     4268
# Name: hate_speech, dtype: int64

# %%
data=data.dropna()

# %%
x=data.iloc[0:,1]
y=data.iloc[0:,0:1]

# %%
x=x.to_numpy()

# %%
y
# Out:
#        hate_speech
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 21078            0
# 21079            0
# 21080            0
# 21081            0
# 21082            0
#
# [21083 rows x 1 columns]

# %%
from imblearn.over_sampling import RandomOverSampler
os=RandomOverSampler(ratio=1)
x_train,y_train=os.fit_resample(x.reshape(-1,1),y)
df= pd.DataFrame(x_train,columns =['tweet'])
df1=pd.DataFrame(y_train,columns=['hate'])
r=pd.concat([df,df1],axis=1)
r
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# ...

# %%
r
# Out:
#                                                                                                                                               tweet  hate
# 0      !!! RT @mayasolovely: As a woman you shouldn't complain about cleaning up your house. &amp; as a man you should always take the trash out...     0
# 1                                                             !!!!! RT @mleew17: boy dats cold...tyga dwn bad for cuffin dat hoe in the 1st place!!     0
# 2                          !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby4life: You ever fuck a bitch and she start to cry? You be confused as shit     0
# 3                                                                                    !!!!!!!!! RT @C_G_Anderson: @viva_based she look like a tranny     0
# 4         !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you hear about me might be true or it might be faker than the bitch who told it to ya &#57361;     0
# ...

# %%
import string
import re
import nltk
from nltk.tokenize import TweetTokenizer

# %%
nlp = spacy.load("en")
sp = spacy.load('en_core_web_sm')

nltk.download('stopwords')
nltk.download('punkt')
spacy_st = nlp.Defaults.stop_words
nltk_st = stopwords.words('english')

def clean(tweet, http = True, punc = True, lem = True, stop_w = True):
    
    if http is True:
        tweet = re.sub("https?:\/\/t.co\/[A-Za-z0-9]*", '', tweet)
    if stop_w == 'nltk':
        tweet = [word for word in word_tokenize(tweet) if not word.lower() in nltk_st]
        tweet = ' '.join(tweet)

    elif stop_w == 'spacy':
        tweet = [word for word in word_tokenize(tweet) if not word.lower() in spacy_st]
        tweet = ' '.join(tweet)

    if lem == True:
        lemmatized = [word.lemma_ for word in sp(tweet)]
        tweet = ' '.join(lemmatized)

    if punc is True:
        tweet = tweet.translate(str.maketrans('', '', string.punctuation))
        
    tweet = re.sub("\s+", ' ', tweet)
    
    return tweet
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
t=[]
for i in range(len(r)):
  a=str(r['tweet'][i])
  v=re.sub('@[A-Za-z0-9_]*','',a)
  v=re.sub('[0-9]+','',v)
  v=re.sub('RT','',v)
  v=v.lower()
  t.append(v)

# %%
g=np.array(t)
d=pd.DataFrame(g,columns=['cleaned_tweet_1'])
r=pd.concat([r,d],axis=1)
r
# Out:
#                                                                                                                                               tweet  ...                                                                                                                cleaned_tweet_1
# 0      !!! RT @mayasolovely: As a woman you shouldn't complain about cleaning up your house. &amp; as a man you should always take the trash out...  ...  !!!  : as a woman you shouldn't complain about cleaning up your house. &amp; as a man you should always take the trash out...
# 1                                                             !!!!! RT @mleew17: boy dats cold...tyga dwn bad for cuffin dat hoe in the 1st place!!  ...                                                     !!!!!  : boy dats cold...tyga dwn bad for cuffin dat hoe in the st place!!
# ...

# %%
r=r.drop(['tweet'],axis=1)

# %%
r['cleaned_text'] = r.cleaned_tweet_1.apply(lambda x: clean(x, lem = False, stop_w = 'nltk', http = True, punc = True))

# %%
r
# Out:
#        hate  ...                                                  cleaned_text
# 0         0  ...   woman nt complain cleaning house amp man always take trash
# 1         0  ...           boy dats cold tyga dwn bad cuffin dat hoe st place
# 2         0  ...                  dawg ever fuck bitch start cry confused shit
# 3         0  ...                                              look like tranny
# 4         0  ...               shit hear might true might faker bitch told ya
# ...     ...  ...                                                           ...
# 33625     1  ...               m gone see baby monkey lil ass anyway funky ass
# 33626     1  ...   bitches got birkins nt even cars island let alone furniture
# 33627     1  ...                                                 thanks bitch
# 33628     1  ...               cowboys best nfc time faggots got shit together
# 33629     1  ...                                boys im retard sometimes time
#
# [33630 rows x 3 columns]

# %%
r=r.drop(['cleaned_tweet_1'],axis=1)

# %%
r
# Out:
#        hate                                                  cleaned_text
# 0         0   woman nt complain cleaning house amp man always take trash
# 1         0           boy dats cold tyga dwn bad cuffin dat hoe st place
# 2         0                  dawg ever fuck bitch start cry confused shit
# 3         0                                              look like tranny
# 4         0               shit hear might true might faker bitch told ya
# ...     ...                                                           ...
# 33625     1               m gone see baby monkey lil ass anyway funky ass
# 33626     1   bitches got birkins nt even cars island let alone furniture
# 33627     1                                                 thanks bitch
# 33628     1               cowboys best nfc time faggots got shit together
# 33629     1                                boys im retard sometimes time
#
# [33630 rows x 2 columns]

# %%
x_train,x_test,y_train,y_test=train_test_split(r['cleaned_text'],r['hate'],test_size=0.25)

# %%
count_vector = CountVectorizer(stop_words = 'english', lowercase = True)

# %%
x_train = count_vector.fit_transform(x_train)
x_test = count_vector.transform(x_test)

# %%
pickle.dump(count_vector,open('/content/drive/MyDrive/hatism/hate_vector.pickle','wb'))

# %%
model1=MultinomialNB()
model1.fit(x_train,y_train)
y_pred=model1.predict(x_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.8014985727878211

# %%
model2=DecisionTreeClassifier()
model2.fit(x_train,y_train)
y_pred=model2.predict(x_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.8785680304471931

# %%
model3=LinearSVC()
model3.fit(x_train,y_train)
y_pred=model3.predict(x_test)
accuracy_score(y_test, y_pred)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# 0.8554947668886774

# %%
model4=RandomForestClassifier()
model4.fit(x_train,y_train)
y_pred=model4.predict(x_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.9094909609895337

# %%
model5=BaggingClassifier()
model5.fit(x_train,y_train)
y_pred=model5.predict(x_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.878686964795433

# %%
model6= LogisticRegression()
model6.fit(x_train,y_train)
y_pred=model6.predict(x_test)
accuracy_score(y_test, y_pred)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# 0.8437202664129401

# %%
model7= SGDClassifier()
model7.fit(x_train,y_train)
y_pred=model7.predict(x_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.8443149381541389

# %%
model8= KNeighborsClassifier()
model8.fit(x_train,y_train)
y_pred=model8.predict(x_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.7866317792578497

# %%
m=pickle.load(open('/content/drive/MyDrive/hatism/hate_vector.pickle','rb'))

# %%
a=['i do not hate you']
a=m.transform(a)
model4.predict(a)
# Out:
# array([1])

# %%
pickle.dump(model4,open('/content/drive/MyDrive/hatism/hate_forest.pickle','wb'))
