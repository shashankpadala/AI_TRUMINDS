# %%
import pandas as pd
import urllib3
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score

# %%
ANNOTATED_COMMENTS_URL = 'https://ndownloader.figshare.com/files/7554634' 
ANNOTATIONS_URL = 'https://ndownloader.figshare.com/files/7554637' 


def download_file(url, fname):
    urllib3.request.urlretrieve(url, fname)

                
download_file(ANNOTATED_COMMENTS_URL, '/content/drive/MyDrive/\personel attacks/comments_user_2004.tar.gz')
download_file(ANNOTATIONS_URL, 'attack_annotations.tsv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-2c72246f229f> in <module>()
#       7
#       8
# ----> 9 download_file(ANNOTATED_COMMENTS_URL, 'attack_annotated_comments.tsv')
#      10 download_file(ANNOTATIONS_URL, 'attack_annotations.tsv')
#
# <ipython-input-5-2c72246f229f> in download_file(url, fname)
#       4
#       5 def download_file(url, fname):
# ----> 6     urllib3.request.urlretrieve(url, fname)
#       7
#       8
#
# AttributeError: module 'urllib3.request' has no attribute 'urlretrieve'

# %%
comments = pd.read_csv('/content/drive/MyDrive/\personel attacks/attack_annotated_comments.tsv', sep = '\t', index_col = 0)
annotations = pd.read_csv('/content/drive/MyDrive/\personel attacks/attack_annotations.tsv',  sep = '\t')

# %%
comments.head()
# Out:
#                                                   comment  year  ...  sample  split
# rev_id                                                           ...
# 37675   `-NEWLINE_TOKENThis is not ``creative``.  Thos...  2002  ...  random  train
# 44816   `NEWLINE_TOKENNEWLINE_TOKEN:: the term ``stand...  2002  ...  random  train
# 49851   NEWLINE_TOKENNEWLINE_TOKENTrue or false, the s...  2002  ...  random  train
# 89320    Next, maybe you could work on being less cond...  2002  ...  random    dev
# 93890                This page will need disambiguation.   2002  ...  random  train
#
# [5 rows x 6 columns]

# %%
labels = annotations.groupby('rev_id')['attack'].mean()>0.5

# %%
comments['attack'] = labels

# %%
comments['comment'] = comments['comment'].apply(lambda x: x.replace("NEWLINE_TOKEN", " "))
comments['comment'] = comments['comment'].apply(lambda x: x.replace("TAB_TOKEN", " "))

# %%
comments.head()
# Out:
#                                                   comment  year  ...  split attack
# rev_id                                                           ...
# 37675   `- This is not ``creative``.  Those are the di...  2002  ...  train  False
# 44816   `  :: the term ``standard model`` is itself le...  2002  ...  train  False
# 49851     True or false, the situation as of March 200...  2002  ...  train  False
# 89320    Next, maybe you could work on being less cond...  2002  ...    dev  False
# 93890                This page will need disambiguation.   2002  ...  train  False
#
# [5 rows x 7 columns]

# %%
train_comments = comments.query("split=='train'")
test_comments = comments.query("split=='test'")

clf = Pipeline([
    ('vect', CountVectorizer(max_features = 10000, ngram_range = (1,2))),
    ('tfidf', TfidfTransformer(norm = 'l2')),
    ('clf', LogisticRegression()),
])
clf = clf.fit(train_comments['comment'], train_comments['attack'])
auc = roc_auc_score(test_comments['attack'], clf.predict_proba(test_comments['comment'])[:, 1])
print('Test ROC AUC: %.3f' %auc)
# Out:
# Test ROC AUC: 0.957

# %%
a=["fuck off"]

# %%
import pickle

# %%
with open('/content/drive/MyDrive/\personel attacks/personel_attacks_model_file', 'wb') as fout:
    pickle.dump(clf, fout)
